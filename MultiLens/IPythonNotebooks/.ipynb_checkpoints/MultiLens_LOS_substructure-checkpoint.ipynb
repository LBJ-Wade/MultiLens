# %% [markdown]
# # MultiLens Code initialisation

# %% [markdown]
# ### this notebooks tests and initialises a multi lens plane

# %%
from MultiLens.lens_assembly import LensAssembly
from MultiLens.Profiles.point_mass import PointMass
from MultiLens.lens_object import LensObject
from MultiLens.Cosmo.cosmo import CosmoProp
import MultiLens.Utils.utils as utils
from MultiLens.MultiLens import MultiLens
from MultiLens.Profiles.gaussian import Gaussian
from MultiLens.numerics import Numerics
import MultiLens.Utils.constants as const
from MultiLens.Utils.halo_param import HaloParam


import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="dark")
from mpl_toolkits.axes_grid1 import AxesGrid, make_axes_locatable
cmap = sns.cubehelix_palette(start=0, light=1, as_cmap=True)

# %%
lensAssembly = LensAssembly()
cosmo = CosmoProp()
multiLens = MultiLens()
gaussian = Gaussian()
numerics = Numerics()
haloParam = HaloParam()

# %% [markdown]
# ## define the lenses

# %%
lens_type = 'SIS' # 'NFW', 'SIS'
lensAssembly.clear()
z = 0.1
mass = 10**4#10**12
pos_x, pos_y = 20, 20
lensObject = LensObject(redshift=z, type=lens_type, approximation='weak', main=False)
if lens_type == 'point_mass':
    kwargs_profile = {'mass': mass, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type=='NFW':
    r200, rho_s, Rs, c = haloParam.profileMain(mass, z)
    kwargs_profile = {'rho_s': rho_s, 'Rs': Rs, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type == 'SIS':
    sigma_v = np.sqrt(2*mass*const.M_sun*const.G/(const.Mpc/1000.))
    print sigma_v/1000
    kwargs_profile = {'sigma_v': sigma_v, 'pos_x': pos_x, 'pos_y': pos_y}
lensObject.add_info('kwargs_profile', kwargs_profile)
lensAssembly.add_lens(lensObject)

z = 0.15
mass = 10**4
pos_x, pos_y = 1, 1
lensObject = LensObject(redshift=z, type=lens_type, approximation='weak', main=False)
if lens_type == 'point_mass':
    kwargs_profile = {'mass': mass, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type=='NFW':
    r200, rho_s, Rs, c = haloParam.profileMain(mass, z)
    kwargs_profile = {'rho_s': rho_s, 'Rs': Rs, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type == 'SIS':
    sigma_v = np.sqrt(2*mass*const.M_sun*const.G/(const.Mpc/1000.))
    print sigma_v/1000
    kwargs_profile = {'sigma_v': sigma_v, 'pos_x': pos_x, 'pos_y': pos_y}
lensObject.add_info('kwargs_profile', kwargs_profile)
lensAssembly.add_lens(lensObject)

z = 0.5
mass = 10**9
pos_x, pos_y = 0.5, 0
lensObject = LensObject(redshift=z, type=lens_type, approximation='weak', main=False)
if lens_type == 'point_mass':
    kwargs_profile = {'mass': mass, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type=='NFW':
    r200, rho_s, Rs, c = haloParam.profileMain(mass, z)
    kwargs_profile = {'rho_s': rho_s, 'Rs': Rs, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type == 'SIS':
    sigma_v = np.sqrt(2*mass*const.M_sun*const.G/(const.Mpc/1000.))
    print sigma_v/1000
    kwargs_profile = {'sigma_v': sigma_v, 'pos_x': pos_x, 'pos_y': pos_y}
lensObject.add_info('kwargs_profile', kwargs_profile)
lensAssembly.add_lens(lensObject)

#lens_type = 'point_mass'

z = 0.295
mass = 10**11
pos_x, pos_y = 0, 0
lensObject = LensObject(redshift=z, type=lens_type, approximation='weak', main=True)
if lens_type == 'point_mass':
    kwargs_profile = {'mass': mass, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type=='NFW':
    r200, rho_s, Rs, c = haloParam.profileMain(mass, z)
    kwargs_profile = {'rho_s': rho_s, 'Rs': Rs, 'pos_x': pos_x, 'pos_y': pos_y}
elif lens_type == 'SIS':
    sigma_v = np.sqrt(2*mass*const.M_sun*const.G/(const.Mpc/1000.))
    print sigma_v
    sigma_v = 400.*1000
    kwargs_profile = {'sigma_v': sigma_v, 'pos_x': pos_x, 'pos_y': pos_y}
lensObject.add_info('kwargs_profile', kwargs_profile)
lensAssembly.add_lens(lensObject)
# Out:
# LensAssembly class cleared. No lens object specified.
# 0.293329626544
# 0.293329626544
# 92.7589725085
# 927589.725085

# %%
lensAssembly.print_info()
x_array, y_array = utils.make_grid(300, 0.01)
# Out:
# Number of lenses =  4
# ==========
# redshift =  0.1
# type =  SIS
# approximation:  weak
# parameters:  {'pos_x': 0.038074876402295177, 'pos_y': 0.038074876402295177, 'sigma_v': 293.3296265438774}
# ==========
# redshift =  0.15
# type =  SIS
# approximation:  weak
# parameters:  {'pos_x': 0.0026978173197932374, 'pos_y': 0.0026978173197932374, 'sigma_v': 293.3296265438774}
# ==========
# This is the main deflector.
# redshift =  0.295
# type =  SIS
# approximation:  weak
# parameters:  {'pos_x': 0.0, 'pos_y': 0.0, 'sigma_v': 400000.0}
# ==========
# redshift =  0.5
# type =  SIS
# approximation:  weak
# parameters:  {'pos_x': 0.0031430379488678007, 'pos_y': 0.0, 'sigma_v': 92758.972508523715}

# %%
z_source = 0.658
beta_x_full, beta_y_full = multiLens.full_ray_tracing(lensAssembly, z_source, x_array, y_array)
beta_x_comb, beta_y_comb = multiLens.combined_ray_tracing(lensAssembly, z_source, x_array, y_array)
beta_x_born, beta_y_born = multiLens.born_ray_tracing(lensAssembly, z_source, x_array, y_array)
beta_x_analytic, beta_y_analytic = multiLens.analytic_mapping(lensAssembly, z_source, x_array, y_array)
beta_x_uncorrected, beta_y_uncorrected = multiLens.analytic_mapping(lensAssembly, z_source, x_array, y_array, LOS_corrected=True)
# Out:
# 1.77793939386e-11 1.77793939386e-11 -1.77793939386e-11 f_xx_k, f_yy_k, f_xy_k
# 1.3935595293e-11 1.3935595293e-11 -1.3935595293e-11 f_xx_k, f_yy_k, f_xy_k
# [[ -8.15596391e-09   8.15596391e-09]
#  [  8.15596391e-09  -8.15596391e-09]] gamma A
# 1.77793939386e-11 1.77793939386e-11 -1.77793939386e-11 f_xx_k, f_yy_k, f_xy_k
# 1.3935595293e-11 1.3935595293e-11 -1.3935595293e-11 f_xx_k, f_yy_k, f_xy_k
# [[ -8.15596391e-09   8.15596391e-09]
#  [  8.15596391e-09  -8.15596391e-09]] gamma A

# %% [markdown]
# ## Gaussian source at (0,0)

# %%
sigma_source = 0.05*const.arcsec
flux_full = gaussian.function(beta_x_full, beta_y_full, amp=1, sigma_x=sigma_source, sigma_y=sigma_source, center_x=0, center_y=0)
flux_comb = gaussian.function(beta_x_comb, beta_y_comb, amp=1, sigma_x=sigma_source, sigma_y=sigma_source, center_x=0, center_y=0)
flux_born = gaussian.function(beta_x_born, beta_y_born, amp=1, sigma_x=sigma_source, sigma_y=sigma_source, center_x=0, center_y=0)
flux_analytic = gaussian.function(beta_x_analytic, beta_y_analytic, amp=1, sigma_x=sigma_source, sigma_y=sigma_source, center_x=0, center_y=0)
flux_uncorrected = gaussian.function(beta_x_uncorrected, beta_y_uncorrected, amp=1, sigma_x=sigma_source, sigma_y=sigma_source, center_x=0, center_y=0)
flux_no_lens = gaussian.function(x_array, y_array, amp=1, sigma_x=sigma_source, sigma_y=sigma_source, center_x=0, center_y=0)

image_full = utils.array2image(flux_full)
image_comb = utils.array2image(flux_comb)
image_born = utils.array2image(flux_born)
image_analytic = utils.array2image(flux_analytic)
image_uncorrected = utils.array2image(flux_uncorrected)
image_no_lens = utils.array2image(flux_no_lens)

# %% [markdown]
# ## numerical mapps

# %%
kappa_full = numerics.kappa(beta_x_full, beta_y_full, x_array, y_array)
kappa_comb = numerics.kappa(beta_x_comb, beta_y_comb, x_array, y_array)
kappa_born = numerics.kappa(beta_x_born, beta_y_born, x_array, y_array)
kappa_analytic = numerics.kappa(beta_x_analytic, beta_y_analytic, x_array, y_array)
kappa_uncorrected = numerics.kappa(beta_x_uncorrected, beta_y_uncorrected, x_array, y_array)

mag_full = numerics.magnification(beta_x_full, beta_y_full, x_array, y_array)
mag_comb = numerics.magnification(beta_x_comb, beta_y_comb, x_array, y_array)
mag_born = numerics.magnification(beta_x_born, beta_y_born, x_array, y_array)
mag_analytic = numerics.magnification(beta_x_analytic, beta_y_analytic, x_array, y_array)
mag_uncorrected = numerics.magnification(beta_x_uncorrected, beta_y_uncorrected, x_array, y_array)

# %%
f, axes = plt.subplots(4, 5, figsize=(16, 12), sharex=False, sharey=False)

ax = axes[0][0]
im=ax.matshow(image_full,origin='lower')
ax.set_title('full')
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[0][1]
im=ax.matshow(image_comb,origin='lower')
ax.set_title('combined')
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[0][2]
im=ax.matshow(image_analytic,origin='lower')
ax.set_title('analytic')
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[0][3]
im=ax.matshow(image_uncorrected,origin='lower')
ax.set_title('straight LOS path after main deflector')
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[0][4]
im=ax.matshow(image_born,origin='lower')
ax.set_title('born')
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)




ax = axes[1][0]
ax.set_title('kappa')
im=ax.matshow(kappa_full,origin='lower', vmin=-1, vmax=1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[1][1]
im=ax.matshow(kappa_comb,origin='lower', vmin=-1, vmax=1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[1][2]
im=ax.matshow(kappa_analytic,origin='lower', vmin=-1, vmax=1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[1][3]
im=ax.matshow(kappa_uncorrected,origin='lower', vmin=-1, vmax=1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[1][4]
im=ax.matshow(kappa_born,origin='lower', vmin=-1, vmax=1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)




ax = axes[2][0]
ax.set_title('kappa - kappa_full')
im=ax.matshow(kappa_full-kappa_full,origin='lower', vmin=-0.1, vmax=0.1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[2][1]
im=ax.matshow(kappa_comb-kappa_full,origin='lower', vmin=-0.1, vmax=0.1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[2][2]
im=ax.matshow(kappa_analytic-kappa_full,origin='lower', vmin=-0.1, vmax=0.1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[2][3]
im=ax.matshow(kappa_uncorrected-kappa_full,origin='lower', vmin=-0.1, vmax=0.1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[2][4]
im=ax.matshow(kappa_born-kappa_full,origin='lower', vmin=-0.1, vmax=0.1)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)



ax = axes[3][0]
ax.set_title('magnification')
im=ax.matshow(mag_full,origin='lower', vmin=-10, vmax=10)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[3][1]
im=ax.matshow(mag_comb,origin='lower', vmin=-10, vmax=10)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[3][2]
im=ax.matshow(mag_analytic,origin='lower', vmin=-10, vmax=10)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[3][3]
im=ax.matshow(mag_uncorrected,origin='lower', vmin=-10, vmax=10)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

ax = axes[3][4]
im=ax.matshow(mag_born,origin='lower', vmin=-10, vmax=10)
plt.setp(ax.get_xticklabels(), visible=False)
plt.setp(ax.get_yticklabels(), visible=False)

f.tight_layout()
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=0.05, hspace=0.05)
plt.show()

# %% [markdown]
# ## check numerics

# %%
x_array_test, y_array_test = utils.make_grid(1000, 0.01)
beta_x_test, beta_y_test = multiLens.full_ray_tracing(lensAssembly, 3, x_array_test, y_array_test)


kappa_test = numerics.kappa(beta_x_test, beta_y_test, x_array_test, y_array_test)
gamma1_test, gamma2_test = numerics.gamma(beta_x_test, beta_y_test, x_array_test, y_array_test)



fig, ax1 = plt.subplots()
im=ax1.matshow(kappa_test,origin='lower', vmin=-1, vmax=1)
plt.axes(ax1)
fig.colorbar(im)
ax1.set_title('kappa')
plt.show()

fig, ax1 = plt.subplots()
im=ax1.matshow(gamma1_test,origin='lower', vmin=-1, vmax=1)
plt.axes(ax1)
fig.colorbar(im)
ax1.set_title('gamma1')
plt.show()

fig, ax1 = plt.subplots()
im=ax1.matshow(gamma2_test,origin='lower', vmin=-1, vmax=1)
plt.axes(ax1)
fig.colorbar(im)
ax1.set_title('gamma2')
plt.show()

# %%
# kappa mapps vs projected mass density

# %%
# magnification ratios of point-like sources (compare between different models)
